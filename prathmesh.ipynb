# %%
#Data loading first step
from langchain_community.document_loaders import TextLoader
loadder = TextLoader('replacment.txt',encoding="utf-8")
loadder

# %%
text_doucuments = loadder.load()
text_doucuments
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\PRATHAMESH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\langchain_community\document_loaders\text.py:42, in TextLoader.lazy_load(self)
#      41 try:
# ---> 42     with open(self.file_path, encoding=self.encoding) as f:
#      43         text = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'replacment.txt'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 text_doucuments = loadder.load()
#       2 text_doucuments
#
# File c:\Users\PRATHAMESH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
# ...

# %%
# Text splitter
from langchain_text_splitters import RecursiveCharacterTextSplitter
textsplitter = RecursiveCharacterTextSplitter(chunk_size=200,chunk_overlap20)

finalDocuments + textsplitter.split_documents(text_documents)
finalDocuments
# Out:
#   Cell In[14], line 3
#     textsplitter = RecursiveCharacterTextSplitter(chunk_size=200,chunk_overlap20)
#                                                                                 ^
# SyntaxError: positional argument follows keyword argument

# %%
#Huggingface embedding
import os 
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
os.environ['HF_Token']= os. getenv('HF_Token')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 os.environ['HF_Token']= os. getenv('HF_Token')
#
# File <frozen os>:714, in _Environ.__setitem__(self, key, value)
#     712 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen os>:774, in _create_environ_mapping.<locals>.check_str(value)
#     772 'Could not get source, probably due dynamically evaluated source code.'
#
# TypeError: str expected, not NoneType

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformer/all-MiniLM-L6-v2")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from langchain_huggingface import HuggingFaceEmbeddings
#       2 embeddings = HuggingFaceEmbeddings(
#       3     model_name="sentence-transformer/all-MiniLM-L6-v2")
#
# ModuleNotFoundError: No module named 'langchain_huggingface'

# %%
print(replacments)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 print(replacments)
#
# NameError: name 'replacments' is not defined

# %%
# vector store in DB
from langchain_community.vectorstores import FAISS
db = FAISS.from_documents (replacement_txt,embeddings)
db
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 3
#       1 # vector store in DB
#       2 from langchain_community.vectorstores import FAISS
# ----> 3 db = FAISS.from_documents (replacement_txt,embeddings)
#       4 db
#
# NameError: name 'replacement_txt' is not defined
